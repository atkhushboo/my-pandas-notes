# %%
import pandas as pd

data={
    "Soap_name":[
        "Neem_Soap",
        "Lemon_Soap",
        "Aloavera_Soap",
        "Rose_Soap",
        "Charcoal_Soap",
        "Milk_Soap"
    ],

    "city":[
        "gurugram",
        "delhi",
        "gurugram",
        "chandigarh",
        "delhi",
        None
    ],

    "Price":[
        150,
        100,
        200,
        180,
        None,
        120
    ],

    "Stock":[
        2000,
        23000,
        14000,
        5000,
        7000,
        None
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#        Soap_name        city  Price    Stock
# 0      Neem_Soap    gurugram  150.0   2000.0
# 1     Lemon_Soap       delhi  100.0  23000.0
# 2  Aloavera_Soap    gurugram  200.0  14000.0
# 3      Rose_Soap  chandigarh  180.0   5000.0
# 4  Charcoal_Soap       delhi    NaN   7000.0
# 5      Milk_Soap        None  120.0      NaN

# %%
#Filtering Data (finding important value)

citydata = df[df["city"] == "gurugram"]
print(citydata)
# Out:
#        Soap_name      city  Price    Stock
# 0      Neem_Soap  gurugram  150.0   2000.0
# 2  Aloavera_Soap  gurugram  200.0  14000.0

# %%
#STRIP() ....USE TO REMOVE unnecessary SPACING

df["Soap_name"]= df["Soap_name"].str.strip()
print(df)
# Out:
#        Soap_name        city  Price    Stock
# 0      Neem_Soap    gurugram  150.0   2000.0
# 1     Lemon_Soap       delhi  100.0  23000.0
# 2  Aloavera_Soap    gurugram  200.0  14000.0
# 3      Rose_Soap  chandigarh  180.0   5000.0
# 4  Charcoal_Soap       delhi    NaN   7000.0
# 5      Milk_Soap        None  120.0      NaN

# %%
#upper().....use to make all alphabets in UPPER CASE

df["Soap_name"]=df["Soap_name"].str.upper()
print(df)
# Out:
#        Soap_name        city  Price    Stock
# 0      NEEM_SOAP    gurugram  150.0   2000.0
# 1     LEMON_SOAP       delhi  100.0  23000.0
# 2  ALOAVERA_SOAP    gurugram  200.0  14000.0
# 3      ROSE_SOAP  chandigarh  180.0   5000.0
# 4  CHARCOAL_SOAP       delhi    NaN   7000.0
# 5      MILK_SOAP        None  120.0      NaN

# %%
#lower()..... use to make all alphabets in LOWER CASE 
df["Soap_name"]=df["Soap_name"].str.lower()
print(df)
# Out:
#        Soap_name        city  Price    Stock
# 0      neem_soap    gurugram  150.0   2000.0
# 1     lemon_soap       delhi  100.0  23000.0
# 2  aloavera_soap    gurugram  200.0  14000.0
# 3      rose_soap  chandigarh  180.0   5000.0
# 4  charcoal_soap       delhi    NaN   7000.0
# 5      milk_soap        None  120.0      NaN

# %%
#USE 2 Methods strip() and lower()
df["Soap_name"]=df["Soap_name"].str.strip().str.lower()
print(df)
# Out:
#        Soap_name        city  Price    Stock
# 0      neem_soap    gurugram  150.0   2000.0
# 1     lemon_soap       delhi  100.0  23000.0
# 2  aloavera_soap    gurugram  200.0  14000.0
# 3      rose_soap  chandigarh  180.0   5000.0
# 4  charcoal_soap       delhi    NaN   7000.0
# 5      milk_soap        None  120.0      NaN

# %%
#Handling Missing Values
#fillna() empty space filling....

df["city"]=df["city"].fillna("Unkown city")
print(df)
# Out:
#        Soap_name         city  Price    Stock
# 0      neem_soap     gurugram  150.0   2000.0
# 1     lemon_soap        delhi  100.0  23000.0
# 2  aloavera_soap     gurugram  200.0  14000.0
# 3      rose_soap   chandigarh  180.0   5000.0
# 4  charcoal_soap        delhi    NaN   7000.0
# 5      milk_soap  Unkown city  120.0      NaN

# %%
#Handling Missing Values
#dropna() removes rows containing missing values
# df=df.dropna()
# print(df)

# %%
#Groupby()....

city_price = df.groupby("city")["Price"].sum()
print(city_price)
# Out:
# city
# Unkown city    120.0
# chandigarh     180.0
# delhi          100.0
# gurugram       350.0
# Name: Price, dtype: float64
